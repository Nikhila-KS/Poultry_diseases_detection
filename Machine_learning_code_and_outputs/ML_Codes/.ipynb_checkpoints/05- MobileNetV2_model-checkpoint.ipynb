# %% [markdown]
# # MobileNetV2 Model

# %%
# Import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image

# Open file
import os
import PIL
from random import seed
# Model CNN (Deep learning network)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense,\
GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Create function plot loss function and accuracy score graph
def plot_graph(model_values):
    ''' 
    Input : Model_values of keras.callbacks.History
    Return : Graph of Loss function and accuracy score between training dataset and vaildation dataset
    '''
    # Subplots
    fig, ax = plt.subplots(1, 2, figsize=(14,5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(model_values.history['loss'], label='Training Loss');
    plt.plot(model_values.history['val_loss'], label='Testing Loss');
    plt.legend(fontsize=12, loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss');
    
    # Plot MSE
    plt.subplot(1, 2, 2)
    
    plt.plot(model_values.history['accuracy'], label='Training Accuracy')
    plt.plot(model_values.history['val_accuracy'], label='Validation Accuracy')
    
    plt.legend(fontsize=12, loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy');

# %% [markdown]
# ## 00- First check GPU

# %%
# https://www.tensorflow.org/guide/keras/sequential_model
# Due to we use Keras Sequential API, 
# We want to check GPU first before training our model for 
# impore efficiency and reduce time. 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18260763107574001789
# xla_global_id: -1
# ]

# %% [markdown]
# ## 01- Open dataset

# %%
# Define the paths
original_dataset_path = r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\poultry_data'
train_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Train"
validation_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Validate"
test_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Test"

# %% [markdown]
# ## 02 Preprocessing image dataset

# %%
# Set parameter of image 
# https://github.com/keras-team/keras/issues/8090#issuecomment-335155737
batch_size = 50 # Set the batch size for epoch cycle
img_height = 128 # Set the height of the picture
img_width = 128 # Set the width of the picture

# Rescale pixel to reduce image size before using in model
data_gen_train = ImageDataGenerator(rescale=1/255.)
data_gen_valid = ImageDataGenerator(rescale=1/255.)
data_gen_test = ImageDataGenerator(rescale=1/255.)

# %%
# Create training dataset
train_dataset = data_gen_train.flow_from_directory(train_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create validation dataset
valid_dataset = data_gen_valid.flow_from_directory(validation_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create testing dataset
test_dataset = data_gen_test.flow_from_directory(test_path,
                                                 class_mode="categorical",
                                                 target_size=(img_height, img_width),
                                                 batch_size=batch_size)
# Out:
# Found 13905 images belonging to 4 classes.
# Found 1738 images belonging to 4 classes.
# Found 1741 images belonging to 4 classes.

# %% [markdown]
# ## 03 MobileNetV2 model training

# %% [markdown]
# ### Transfer learning

# %%
# https://keras.io/api/applications/mobilenet/#mobilenetv2-function
# import MobileNetV2 model form keras API
# set input size of image of trianing is 128x128 (smallest size of MobileNetV2)
# due to we want to use transfer learning process 
# we must add `include_top=False` because we wan to add our input data 
# we decide default weigh for mode
mobv2_model = tf.keras.applications.MobileNetV2(input_shape=(128,128,3),
                                                include_top=False, # Transfer learning
                                                weights="imagenet")
# Out:
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 6s 1us/step

# %%
# model summary
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
mobv2_model.summary()
# Out:
# Model: "mobilenetv2_1.00_128"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 2223872 (8.48 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
# fix weights and bias 
# train specifically custom head
mobv2_model.trainable=False

# %% [markdown]
# ### Add custom head and output layers

# %%
# Create output layer 
# We have 4 classes in our output we decide using activation="softmax" 
# for multi classification.
# Before output layer we decide use GlobalAveragePooling2D as 
# one type of flatten layer.
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(mobv2_model.output) # flatten
prediction_layer = tf.keras.layers.Dense(units=4, activation="softmax")(average_pooling_layer)

# %%
# Add Input layer and output layer 
model = tf.keras.models.Model(inputs=mobv2_model.input, 
                                    outputs=prediction_layer)

# %%
# Total params: 2,263,108
# Trainable params: 5,124 # add input layers and  output layers
# Non-trainable params: 2,257,984 --> fix layers
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 64, 64, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 64, 64, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 64, 64, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 64, 64, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 64, 64, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 64, 64, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 64, 64, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 64, 64, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 64, 64, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 64, 64, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 65, 65, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 32, 32, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 32, 32, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 32, 32, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 32, 32, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 32, 32, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 32, 32, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 32, 32, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 32, 32, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 32, 32, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 32, 32, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 33, 33, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 16, 16, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 16, 16, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 16, 16, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 16, 16, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 16, 16, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 16, 16, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 16, 16, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 16, 16, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 16, 16, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 16, 16, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 16, 16, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 17, 17, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 8, 8, 192)            1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 8, 8, 192)            768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 8, 8, 192)            0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 8, 8, 64)             12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 8, 8, 64)             0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 8, 8, 64)             0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 8, 8, 384)            24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 8, 8, 384)            1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 8, 8, 384)            0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 8, 8, 384)            3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 8, 8, 384)            1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 8, 8, 384)            0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 8, 8, 64)             24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 8, 8, 64)             256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 8, 8, 64)             0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 8, 8, 384)            24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 8, 8, 384)            1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 8, 8, 384)            0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 8, 8, 384)            3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 8, 8, 384)            1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 8, 8, 384)            0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 8, 8, 96)             36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 8, 8, 96)             384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 8, 8, 96)             384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 8, 8, 96)             0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 8, 8, 96)             55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 8, 8, 96)             384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 8, 8, 96)             0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 8, 8, 576)            55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 8, 8, 576)            2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 8, 8, 576)            0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 9, 9, 576)            0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 4, 4, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 4, 4, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 4, 4, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 4, 4, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 4, 4, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 4, 4, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 4, 4, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 4, 4, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 4, 4, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 4, 4, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 4, 4, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 4, 4, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 4, 4, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 4, 4, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 4, 4, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 4, 4, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 4, 4, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 4, 4, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 4, 4, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 4, 4, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 4, 4, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                    5124      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 2263108 (8.63 MB)
# Trainable params: 5124 (20.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
# Compile the model         
model.compile(loss="categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
# Save checkpoints during training
checkpoint_path = r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 mode="max",
                                                 verbose=1,
                                                 monitor="val_accuracy")

# %%
# Training model
# make sure you truely save checkpoint_path
history = model.fit(train_dataset,
          epochs=25,
          validation_data=valid_dataset,
          callbacks=[cp_callback])
# Out:
# Epoch 1/25
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 279/279 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8647
# Epoch 1: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 872s 3s/step - loss: 0.3676 - accuracy: 0.8647 - val_loss: 0.2268 - val_accuracy: 0.9183
# Epoch 2/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1895 - accuracy: 0.9340
# Epoch 2: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 824s 3s/step - loss: 0.1895 - accuracy: 0.9340 - val_loss: 0.1820 - val_accuracy: 0.9402
# Epoch 3/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9476
# Epoch 3: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 753s 3s/step - loss: 0.1540 - accuracy: 0.9476 - val_loss: 0.1580 - val_accuracy: 0.9448
# Epoch 4/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9556
# Epoch 4: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 749s 3s/step - loss: 0.1327 - accuracy: 0.9556 - val_loss: 0.1359 - val_accuracy: 0.9511
# Epoch 5/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9602
# Epoch 5: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 826s 3s/step - loss: 0.1187 - accuracy: 0.9602 - val_loss: 0.1257 - val_accuracy: 0.9580
# Epoch 6/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9635
# Epoch 6: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 814s 3s/step - loss: 0.1088 - accuracy: 0.9635 - val_loss: 0.1198 - val_accuracy: 0.9626
# Epoch 7/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9677
# Epoch 7: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 734s 3s/step - loss: 0.0998 - accuracy: 0.9677 - val_loss: 0.1203 - val_accuracy: 0.9603
# Epoch 8/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9712
# Epoch 8: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 650s 2s/step - loss: 0.0898 - accuracy: 0.9712 - val_loss: 0.1088 - val_accuracy: 0.9626
# Epoch 9/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9734
# Epoch 9: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 805s 3s/step - loss: 0.0839 - accuracy: 0.9734 - val_loss: 0.1094 - val_accuracy: 0.9597
# Epoch 10/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9757
# Epoch 10: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 806s 3s/step - loss: 0.0784 - accuracy: 0.9757 - val_loss: 0.1095 - val_accuracy: 0.9614
# Epoch 11/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9766
# Epoch 11: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 730s 3s/step - loss: 0.0739 - accuracy: 0.9766 - val_loss: 0.1017 - val_accuracy: 0.9632
# Epoch 12/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9781
# Epoch 12: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 683s 2s/step - loss: 0.0707 - accuracy: 0.9781 - val_loss: 0.0972 - val_accuracy: 0.9672
# Epoch 13/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9804
# Epoch 13: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 666s 2s/step - loss: 0.0653 - accuracy: 0.9804 - val_loss: 0.0985 - val_accuracy: 0.9666
# Epoch 14/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9802
# Epoch 14: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 667s 2s/step - loss: 0.0629 - accuracy: 0.9802 - val_loss: 0.1010 - val_accuracy: 0.9609
# Epoch 15/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9819
# Epoch 15: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 672s 2s/step - loss: 0.0602 - accuracy: 0.9819 - val_loss: 0.0982 - val_accuracy: 0.9643
# Epoch 16/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9819
# Epoch 16: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 740s 3s/step - loss: 0.0574 - accuracy: 0.9819 - val_loss: 0.0976 - val_accuracy: 0.9672
# Epoch 17/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9831
# Epoch 17: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 703s 3s/step - loss: 0.0543 - accuracy: 0.9831 - val_loss: 0.0989 - val_accuracy: 0.9643
# Epoch 18/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9850
# Epoch 18: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 643s 2s/step - loss: 0.0506 - accuracy: 0.9850 - val_loss: 0.0966 - val_accuracy: 0.9672
# Epoch 19/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9851
# Epoch 19: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 723s 3s/step - loss: 0.0502 - accuracy: 0.9851 - val_loss: 0.0957 - val_accuracy: 0.9638
# Epoch 20/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9875
# Epoch 20: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 797s 3s/step - loss: 0.0470 - accuracy: 0.9875 - val_loss: 0.0988 - val_accuracy: 0.9684
# Epoch 21/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9871
# Epoch 21: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 825s 3s/step - loss: 0.0447 - accuracy: 0.9871 - val_loss: 0.1050 - val_accuracy: 0.9626
# Epoch 22/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9880
# Epoch 22: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 797s 3s/step - loss: 0.0425 - accuracy: 0.9880 - val_loss: 0.1049 - val_accuracy: 0.9609
# Epoch 23/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9873
# Epoch 23: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 824s 3s/step - loss: 0.0425 - accuracy: 0.9873 - val_loss: 0.1057 - val_accuracy: 0.9597
# Epoch 24/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9885
# Epoch 24: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 821s 3s/step - loss: 0.0407 - accuracy: 0.9885 - val_loss: 0.0994 - val_accuracy: 0.9632
# Epoch 25/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9899
# Epoch 25: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_cp\cp.ckpt
# 279/279 [==============================] - 965s 3s/step - loss: 0.0381 - accuracy: 0.9899 - val_loss: 0.0963 - val_accuracy: 0.9661

# %%
# plot graph 
plot_graph(history)


# overfitting between training and validation 
# Final accuracy after training 25 epochs is score in training 0.98% 
# and vaildaion 0.90%
# Loss function after training 25 epochs is score in training 0.06% 
# and vaildaion 0.31%
# Goof perfomance than baseline model

# %%
# save model
model.save(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2.h5")
# Out:
# C:\Users\HP\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# convert the history.history dict to a pandas DataFrame:    
hist_df = pd.DataFrame(history.history) 
# # save history to csv:  
# hist_csv_file = r"C:\Users\HP\Desktop\Data\poultry_new\model\mobilenetV2\history_mobilenetv2_tf.csv"
# with open(hist_csv_file, mode='w') as f:
#     hist_df.to_csv(f)

# Save history to CSV file
hist_csv_file = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\history_mobilenetv2_tl.csv"
hist_df.to_csv(hist_csv_file, index=False)  # Set index=False to exclude the index column

hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.367616  0.864653  0.226754      0.918297
# 1  0.189491  0.933981  0.181951      0.940161
# 2  0.154031  0.947645  0.158021      0.944764
# 3  0.132680  0.955628  0.135918      0.951093
# 4  0.118726  0.960230  0.125708      0.957998

# %% [markdown]
# ### Fine Tuning

# %%
img_height = 128 # Set the height of the picture
img_width = 128 # Set the width of the picture

# load model
mobv2_model = tf.keras.applications.MobileNetV2(input_shape=(img_height, img_width,3),
                                              include_top=False, # Transfer learning
                                              weights="imagenet",
                                              )  

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(mobv2_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in mobv2_model.layers[:fine_tune_at]:
    layer.trainable = False

# Make sure you have frozen the correct layers
for i, layer in enumerate(mobv2_model.layers):
    if i >= 95:
        print(i, layer.name, layer.trainable)

# Add input layers and output layers
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(mobv2_model.output) # flatten
prediction_layer = tf.keras.layers.Dense(units=4, activation="softmax")(average_pooling_layer)
fineture_model = tf.keras.models.Model(inputs=mobv2_model.input, 
                                     outputs=prediction_layer)

# Compile the model         
fineture_model.compile(loss="categorical_crossentropy", 
                       optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                       metrics=['accuracy'])
# Out:
# Number of layers in the base model:  154
# 95 block_10_depthwise_relu False
# 96 block_10_project False
# 97 block_10_project_BN False
# 98 block_11_expand False
# 99 block_11_expand_BN False
# 100 block_11_expand_relu True
# 101 block_11_depthwise True
# 102 block_11_depthwise_BN True
# 103 block_11_depthwise_relu True
# 104 block_11_project True
# 105 block_11_project_BN True
# 106 block_11_add True
# 107 block_12_expand True
# 108 block_12_expand_BN True
# 109 block_12_expand_relu True
# 110 block_12_depthwise True
# 111 block_12_depthwise_BN True
# 112 block_12_depthwise_relu True
# 113 block_12_project True
# 114 block_12_project_BN True
# 115 block_12_add True
# 116 block_13_expand True
# 117 block_13_expand_BN True
# 118 block_13_expand_relu True
# 119 block_13_pad True
# 120 block_13_depthwise True
# 121 block_13_depthwise_BN True
# 122 block_13_depthwise_relu True
# 123 block_13_project True
# 124 block_13_project_BN True
# 125 block_14_expand True
# 126 block_14_expand_BN True
# 127 block_14_expand_relu True
# 128 block_14_depthwise True
# 129 block_14_depthwise_BN True
# 130 block_14_depthwise_relu True
# 131 block_14_project True
# 132 block_14_project_BN True
# 133 block_14_add True
# 134 block_15_expand True
# 135 block_15_expand_BN True
# 136 block_15_expand_relu True
# 137 block_15_depthwise True
# 138 block_15_depthwise_BN True
# 139 block_15_depthwise_relu True
# 140 block_15_project True
# 141 block_15_project_BN True
# 142 block_15_add True
# 143 block_16_expand True
# 144 block_16_expand_BN True
# 145 block_16_expand_relu True
# 146 block_16_depthwise True
# 147 block_16_depthwise_BN True
# 148 block_16_depthwise_relu True
# 149 block_16_project True
# 150 block_16_project_BN True
# 151 Conv_1 True
# 152 Conv_1_bn True
# 153 out_relu True

# %%
# Save checkpoints during training
# follow value of vaildation scorce 
checkpoint = tf.keras.callbacks.ModelCheckpoint(r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5', 
                             monitor= 'val_accuracy', 
                             mode= 'max', 
                             save_best_only = True, 
                             verbose= 1)

# %%
# Training model
# make sure you truely save checkpoint_path
history_ft = fineture_model.fit(train_dataset,  
                             epochs=25, 
                             validation_data=valid_dataset, 
                             callbacks=[checkpoint]) # fine tune continue form transfer learning
# Out:
# Epoch 1/25
# 279/279 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9325
# Epoch 1: val_accuracy improved from -inf to 0.52359, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# C:\Users\HP\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 279/279 [==============================] - 1270s 5s/step - loss: 0.2126 - accuracy: 0.9325 - val_loss: 8.5257 - val_accuracy: 0.5236
# Epoch 2/25
# 279/279 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9657
# Epoch 2: val_accuracy improved from 0.52359 to 0.75604, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# 279/279 [==============================] - 1256s 5s/step - loss: 0.1012 - accuracy: 0.9657 - val_loss: 2.6800 - val_accuracy: 0.7560
# Epoch 3/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9757
# Epoch 3: val_accuracy improved from 0.75604 to 0.76755, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# 279/279 [==============================] - 750s 3s/step - loss: 0.0735 - accuracy: 0.9757 - val_loss: 4.2502 - val_accuracy: 0.7675
# Epoch 4/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9841
# Epoch 4: val_accuracy improved from 0.76755 to 0.90104, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# 279/279 [==============================] - 720s 3s/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 1.0325 - val_accuracy: 0.9010
# Epoch 5/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9811
# Epoch 5: val_accuracy did not improve from 0.90104
# 279/279 [==============================] - 728s 3s/step - loss: 0.0583 - accuracy: 0.9811 - val_loss: 1.9220 - val_accuracy: 0.8314
# Epoch 6/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9862
# Epoch 6: val_accuracy did not improve from 0.90104
# 279/279 [==============================] - 724s 3s/step - loss: 0.0410 - accuracy: 0.9862 - val_loss: 7.2625 - val_accuracy: 0.6220
# Epoch 7/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9914
# Epoch 7: val_accuracy improved from 0.90104 to 0.97986, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# 279/279 [==============================] - 726s 3s/step - loss: 0.0265 - accuracy: 0.9914 - val_loss: 0.1388 - val_accuracy: 0.9799
# Epoch 8/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9937
# Epoch 8: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 728s 3s/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 2.1541 - val_accuracy: 0.8049
# Epoch 9/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9786
# Epoch 9: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 723s 3s/step - loss: 0.0668 - accuracy: 0.9786 - val_loss: 9.6091 - val_accuracy: 0.5806
# Epoch 10/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9892
# Epoch 10: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 725s 3s/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 2.2080 - val_accuracy: 0.8257
# Epoch 11/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9817
# Epoch 11: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 725s 3s/step - loss: 0.0550 - accuracy: 0.9817 - val_loss: 1.4363 - val_accuracy: 0.8389
# Epoch 12/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9950
# Epoch 12: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 727s 3s/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.1675 - val_accuracy: 0.9672
# Epoch 13/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9813
# Epoch 13: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 724s 3s/step - loss: 0.0565 - accuracy: 0.9813 - val_loss: 0.6030 - val_accuracy: 0.9252
# Epoch 14/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9935
# Epoch 14: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 726s 3s/step - loss: 0.0217 - accuracy: 0.9935 - val_loss: 0.6267 - val_accuracy: 0.9206
# Epoch 15/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9918
# Epoch 15: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 725s 3s/step - loss: 0.0289 - accuracy: 0.9918 - val_loss: 3.6467 - val_accuracy: 0.7411
# Epoch 16/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9868
# Epoch 16: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 724s 3s/step - loss: 0.0408 - accuracy: 0.9868 - val_loss: 0.7266 - val_accuracy: 0.9206
# Epoch 17/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9962
# Epoch 17: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 726s 3s/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.1991 - val_accuracy: 0.9730
# Epoch 18/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9970
# Epoch 18: val_accuracy did not improve from 0.97986
# 279/279 [==============================] - 724s 3s/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.1584 - val_accuracy: 0.9735
# Epoch 19/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9963
# Epoch 19: val_accuracy improved from 0.97986 to 0.98389, saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\ft_cp\mobilenetv2_ft.h5
# 279/279 [==============================] - 721s 3s/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.0846 - val_accuracy: 0.9839
# Epoch 20/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980
# Epoch 20: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 725s 3s/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.6830 - val_accuracy: 0.9028
# Epoch 21/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9947
# Epoch 21: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 721s 3s/step - loss: 0.0156 - accuracy: 0.9947 - val_loss: 0.2784 - val_accuracy: 0.9632
# Epoch 22/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9947
# Epoch 22: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 725s 3s/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 1.0526 - val_accuracy: 0.9125
# Epoch 23/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977
# Epoch 23: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 721s 3s/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.2024 - val_accuracy: 0.9724
# Epoch 24/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9970
# Epoch 24: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 722s 3s/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.5386 - val_accuracy: 0.9482
# Epoch 25/25
# 279/279 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9973
# Epoch 25: val_accuracy did not improve from 0.98389
# 279/279 [==============================] - 723s 3s/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.2476 - val_accuracy: 0.9781

# %%
# plot graph 
plot_graph(history_ft)

# Slightly Overfitting between training and validation 
# Final accuracy after fine tuning 25 epochs is up score in training 1.00% (at 23 epoch) 
# and vaildaion 0.93% (better than transfer learning)
# Loss function after training 25 epochs is down score in training 0.01%  (at 23 epoch)
# and vaildaion 0.78% (worse than transfer learning)
# Higher perfomance than baseline model

# %%
# save model after fine tuning
fineture_model.save(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_ft.h5")

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history_ft.history) 

# # save to csv: 
# hist_csv_file = '../model/mobilenetV2/history_mobilenetv2_ft.csv'
# with open(hist_csv_file, mode='w') as f:
#     hist_df.to_csv(f)

# Save history to CSV file
hist_csv_file = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\history_mobilenetv2_ft.csv"
hist_df.to_csv(hist_csv_file, index=False)  # Set index=False to exclude the index column

hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.212576  0.932542  8.525651      0.523590
# 1  0.101161  0.965696  2.680012      0.756041
# 2  0.073468  0.975692  4.250154      0.767549
# 3  0.045650  0.984106  1.032479      0.901036
# 4  0.058345  0.981086  1.921999      0.831415

# %% [markdown]
# ## Convert to TfLite

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_ft.h5")
# "C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_ft.h5"

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open(r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\mobilenetv2\mobilenetv2_ft_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpmk6wy996\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpmk6wy996\assets
