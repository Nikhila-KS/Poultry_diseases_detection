# %% [markdown]
# # Convolutional Neural Network

# %%
# Import librarys
# normal 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# open file
from IPython.display import Image
import os
import PIL

# model CNN (Deep learning network)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense,\
GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Create function plot loss function and accuracy score graph
def plot_graph(model_values):
    ''' 
    Input : Model_values of keras.callbacks.History
    Return : Graph of Loss function and accuracy score between training dataset and vaildation dataset
    '''
    # Subplots
    fig, ax = plt.subplots(1, 2, figsize=(14,5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(model_values.history['loss'], label='Training Loss');
    plt.plot(model_values.history['val_loss'], label='Testing Loss');
    plt.legend(fontsize=12, loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss');
    
    # Plot MSE
    plt.subplot(1, 2, 2)
    
    plt.plot(model_values.history['accuracy'], label='Training Accuracy')
    plt.plot(model_values.history['val_accuracy'], label='Validation Accuracy')
    
    plt.legend(fontsize=12, loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy');

# %% [markdown]
# ## 00-Check GPU/CPU

# %%
# https://www.tensorflow.org/guide/keras/sequential_model
# Due to we use Keras Sequential API, 
# We want to check GPU first before training our model for 
# impore efficiency and reduce time. 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11981346038949460383
# xla_global_id: -1
# ]

# %% [markdown]
# ## 01-Open datasets

# %%
# Define the paths
original_dataset_path = r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\poultry_data'
train_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Train"
validation_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Validate"
test_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Test"

# %% [markdown]
# ## 02-Preprocessing image dataset

# %%
# Set parameters for image size and batch size
img_height = 224
img_width = 224
batch_size = 25

# %%
# Rescale pixel values to reduce image size before using in the model
data_gen_train = ImageDataGenerator(rescale=1/255.)
data_gen_valid = ImageDataGenerator(rescale=1/255.)
data_gen_test = ImageDataGenerator(rescale=1/255.)

# %%
# Create training dataset
train_dataset = data_gen_train.flow_from_directory(train_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create validation dataset
valid_dataset = data_gen_valid.flow_from_directory(validation_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create testing dataset
test_dataset = data_gen_test.flow_from_directory(test_path,
                                                 class_mode="categorical",
                                                 target_size=(img_height, img_width),
                                                 batch_size=batch_size)
# Out:
# Found 13905 images belonging to 4 classes.
# Found 1738 images belonging to 4 classes.
# Found 1741 images belonging to 4 classes.

# %%
# Display class distribution in the training dataset
print("Classes in the training dataset:")
print(pd.Series(train_dataset.classes).value_counts(normalize=True).mul(100))
print("Class indices:", train_dataset.class_indices)
# Out:
# Classes in the training dataset:
# 3    26.184826
# 2    25.954693
# 0    24.192736
# 1    23.667745
# Name: proportion, dtype: float64
# Class indices: {'Coccidiosis': 0, 'Healthy poultry': 1, 'Newcastle diseases': 2, 'Salmonella': 3}

# %%
# Display class distribution in the validation dataset
print("\nClasses in the validation dataset:")
print(pd.Series(valid_dataset.classes).value_counts())
# Out:
# Classes in the validation dataset:
# 3    455
# 2    451
# 0    421
# 1    411
# Name: count, dtype: int64

# %%
# Display class distribution in the testing dataset
print("\nClasses in the testing dataset:")
print(pd.Series(test_dataset.classes).value_counts())
# Out:
# Classes in the testing dataset:
# 3    456
# 2    452
# 0    421
# 1    412
# Name: count, dtype: int64

# %%
# show some image sample in training dataset
images, labels_class = next(train_dataset)
classes = train_dataset.class_indices
plt.figure(figsize=(7, 7))
for i in range(9):
    label = [j for j in classes if classes[j] == np.argmax(labels_class[i])][0]
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow((images[i]*255.).astype("uint8"))
    plt.title(label)
    plt.axis("off")

# %%
# Recheck after rescale
print(images[0].max())
print(images[0].min())
# Out:
# 1.0
# 0.0

# %% [markdown]
# ## 03-CNN model training

# %%
# Training model
# Compile the model
model = Sequential()

# Input layer
model.add(Conv2D(16,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same', input_shape=(224,224,3))) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same  
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) 
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Flatten()) # convert all the resultant 2-Dimensional arrays into a single long continuous linear vector
model.add(Dense(64, activation='relu',
                kernel_initializer='he_uniform'))

# avoid overfitting!
model.add(Dropout(0.5))

# Output layer
model.add(Dense(4, activation='softmax'))

# Compile the model         
model.compile(loss="categorical_crossentropy", 
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# we have 2,102,564 nodes for training
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        4640
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 416084 (1.59 MB)
# Trainable params: 416084 (1.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Save checkpoints during training
checkpoint_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# training model 
# make sure you truely save checkpoint_path
history = model.fit(train_dataset,
                              epochs=25,
                              validation_data=valid_dataset,
                              callbacks=[cp_callback])
# Out:
# Epoch 1/25
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 557/557 [==============================] - ETA: 0s - loss: 0.8017 - accuracy: 0.6708
# Epoch 1: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 835s 1s/step - loss: 0.8017 - accuracy: 0.6708 - val_loss: 0.4725 - val_accuracy: 0.8412
# Epoch 2/25
# 557/557 [==============================] - ETA: 0s - loss: 0.4514 - accuracy: 0.8452
# Epoch 2: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 775s 1s/step - loss: 0.4514 - accuracy: 0.8452 - val_loss: 0.3105 - val_accuracy: 0.9016
# Epoch 3/25
# 557/557 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8729
# Epoch 3: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 833s 1s/step - loss: 0.3674 - accuracy: 0.8729 - val_loss: 0.2986 - val_accuracy: 0.9033
# Epoch 4/25
# 557/557 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8893
# Epoch 4: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 814s 1s/step - loss: 0.3324 - accuracy: 0.8893 - val_loss: 0.2303 - val_accuracy: 0.9217
# Epoch 5/25
# 557/557 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9095
# Epoch 5: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 797s 1s/step - loss: 0.2706 - accuracy: 0.9095 - val_loss: 0.3692 - val_accuracy: 0.8884
# Epoch 6/25
# 557/557 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9187
# Epoch 6: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 730s 1s/step - loss: 0.2411 - accuracy: 0.9187 - val_loss: 0.2248 - val_accuracy: 0.9269
# Epoch 7/25
# 557/557 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9221
# Epoch 7: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 726s 1s/step - loss: 0.2315 - accuracy: 0.9221 - val_loss: 0.1808 - val_accuracy: 0.9453
# Epoch 8/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9310
# Epoch 8: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 740s 1s/step - loss: 0.1966 - accuracy: 0.9310 - val_loss: 0.1855 - val_accuracy: 0.9522
# Epoch 9/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9386
# Epoch 9: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 735s 1s/step - loss: 0.1827 - accuracy: 0.9386 - val_loss: 0.1672 - val_accuracy: 0.9436
# Epoch 10/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9415
# Epoch 10: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 741s 1s/step - loss: 0.1595 - accuracy: 0.9415 - val_loss: 0.1586 - val_accuracy: 0.9545
# Epoch 11/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9478
# Epoch 11: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 756s 1s/step - loss: 0.1613 - accuracy: 0.9478 - val_loss: 0.1403 - val_accuracy: 0.9586
# Epoch 12/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9464
# Epoch 12: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 737s 1s/step - loss: 0.1544 - accuracy: 0.9464 - val_loss: 0.1779 - val_accuracy: 0.9430
# Epoch 13/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9522
# Epoch 13: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 745s 1s/step - loss: 0.1381 - accuracy: 0.9522 - val_loss: 0.1407 - val_accuracy: 0.9586
# Epoch 14/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9560
# Epoch 14: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 923s 2s/step - loss: 0.1271 - accuracy: 0.9560 - val_loss: 0.1185 - val_accuracy: 0.9620
# Epoch 15/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9581
# Epoch 15: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 1264s 2s/step - loss: 0.1184 - accuracy: 0.9581 - val_loss: 0.1633 - val_accuracy: 0.9643
# Epoch 16/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9627
# Epoch 16: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 1269s 2s/step - loss: 0.1054 - accuracy: 0.9627 - val_loss: 0.1242 - val_accuracy: 0.9666
# Epoch 17/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9690
# Epoch 17: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 772s 1s/step - loss: 0.0929 - accuracy: 0.9690 - val_loss: 0.1840 - val_accuracy: 0.9517
# Epoch 18/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9689
# Epoch 18: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 728s 1s/step - loss: 0.0902 - accuracy: 0.9689 - val_loss: 0.1060 - val_accuracy: 0.9758
# Epoch 19/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9658
# Epoch 19: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 726s 1s/step - loss: 0.0987 - accuracy: 0.9658 - val_loss: 0.0868 - val_accuracy: 0.9735
# Epoch 20/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9695
# Epoch 20: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 742s 1s/step - loss: 0.0884 - accuracy: 0.9695 - val_loss: 0.0971 - val_accuracy: 0.9712
# Epoch 21/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9767
# Epoch 21: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 740s 1s/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.0899 - val_accuracy: 0.9718
# Epoch 22/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9730
# Epoch 22: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 744s 1s/step - loss: 0.0837 - accuracy: 0.9730 - val_loss: 0.0872 - val_accuracy: 0.9712
# Epoch 23/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9759
# Epoch 23: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 745s 1s/step - loss: 0.0740 - accuracy: 0.9759 - val_loss: 0.0971 - val_accuracy: 0.9758
# Epoch 24/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9766
# Epoch 24: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 743s 1s/step - loss: 0.0718 - accuracy: 0.9766 - val_loss: 0.0826 - val_accuracy: 0.9730
# Epoch 25/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9740
# Epoch 25: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 719s 1s/step - loss: 0.0840 - accuracy: 0.9740 - val_loss: 0.0756 - val_accuracy: 0.9793

# %%
# plot graph 
plot_graph(history)

# %%
# save model
model.save(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model.h5")
# Out:
# C:\Users\HP\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# create dataframe to save in .csv file
hist_df = pd.DataFrame(history.history) 
hist_df.head()

# Save history to CSV file
hist_csv_file = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\history_cnn_model16.csv"
hist_df.to_csv(hist_csv_file, index=False)  # Set index=False to exclude the index column

# %% [markdown]
# ## Convert to TfLite

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model.h5")

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open(r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-1\cnn_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmp29qthy1a\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmp29qthy1a\assets
