# %% [markdown]
# # Convolutional Neural Network

# %%
# Import librarys
# normal 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# open file
from IPython.display import Image
import os
import PIL

# model CNN (Deep learning network)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense,\
GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# WARNING:tensorflow:From C:\Users\HP\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Create function plot loss function and accuracy score graph
def plot_graph(model_values):
    ''' 
    Input : Model_values of keras.callbacks.History
    Return : Graph of Loss function and accuracy score between training dataset and vaildation dataset
    '''
    # Subplots
    fig, ax = plt.subplots(1, 2, figsize=(14,5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(model_values.history['loss'], label='Training Loss');
    plt.plot(model_values.history['val_loss'], label='Testing Loss');
    plt.legend(fontsize=12, loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss');
    
    # Plot MSE
    plt.subplot(1, 2, 2)
    
    plt.plot(model_values.history['accuracy'], label='Training Accuracy')
    plt.plot(model_values.history['val_accuracy'], label='Validation Accuracy')
    
    plt.legend(fontsize=12, loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy');

# %% [markdown]
# ## 00-Check GPU/CPU

# %%
# https://www.tensorflow.org/guide/keras/sequential_model
# Due to we use Keras Sequential API, 
# We want to check GPU first before training our model for 
# impore efficiency and reduce time. 
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17261141069845006181
# xla_global_id: -1
# ]

# %% [markdown]
# ## 01-Open datasets

# %%
# Define the paths
original_dataset_path = r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\poultry_data'
train_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Train"
validation_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Validate"
test_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\Test"

# %% [markdown]
# ## 02-Preprocessing image dataset

# %%
# Set parameters for image size and batch size
img_height = 224
img_width = 224
batch_size = 25

# %%
# Rescale pixel values to reduce image size before using in the model
data_gen_train = ImageDataGenerator(rescale=1/255.)
data_gen_valid = ImageDataGenerator(rescale=1/255.)
data_gen_test = ImageDataGenerator(rescale=1/255.)

# %%
# Create training dataset
train_dataset = data_gen_train.flow_from_directory(train_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create validation dataset
valid_dataset = data_gen_valid.flow_from_directory(validation_path,
                                                   class_mode="categorical",
                                                   target_size=(img_height, img_width),
                                                   batch_size=batch_size)

# Create testing dataset
test_dataset = data_gen_test.flow_from_directory(test_path,
                                                 class_mode="categorical",
                                                 target_size=(img_height, img_width),
                                                 batch_size=batch_size)
# Out:
# Found 13905 images belonging to 4 classes.
# Found 1738 images belonging to 4 classes.
# Found 1741 images belonging to 4 classes.

# %%
# Display class distribution in the training dataset
print("Classes in the training dataset:")
print(pd.Series(train_dataset.classes).value_counts(normalize=True).mul(100))
print("Class indices:", train_dataset.class_indices)
# Out:
# Classes in the training dataset:
# 3    26.184826
# 2    25.954693
# 0    24.192736
# 1    23.667745
# Name: proportion, dtype: float64
# Class indices: {'Coccidiosis': 0, 'Healthy poultry': 1, 'Newcastle diseases': 2, 'Salmonella': 3}

# %%
# Display class distribution in the validation dataset
print("\nClasses in the validation dataset:")
print(pd.Series(valid_dataset.classes).value_counts())
# Out:
# Classes in the validation dataset:
# 3    455
# 2    451
# 0    421
# 1    411
# Name: count, dtype: int64

# %%
# Display class distribution in the testing dataset
print("\nClasses in the testing dataset:")
print(pd.Series(test_dataset.classes).value_counts())
# Out:
# Classes in the testing dataset:
# 3    456
# 2    452
# 0    421
# 1    412
# Name: count, dtype: int64

# %%
# show some image sample in training dataset
images, labels_class = next(train_dataset)
classes = train_dataset.class_indices
plt.figure(figsize=(7, 7))
for i in range(9):
    label = [j for j in classes if classes[j] == np.argmax(labels_class[i])][0]
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow((images[i]*255.).astype("uint8"))
    plt.title(label)
    plt.axis("off")

# %%
# Recheck after rescale
print(images[0].max())
print(images[0].min())
# Out:
# 1.0
# 0.0

# %% [markdown]
# ## 03-CNN model training

# %%
# Training model
# Compile the model
model = Sequential()

# Input layer
model.add(Conv2D(16,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same', input_shape=(224,224,3))) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same  
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) 
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Conv2D(32,(3,3), activation='relu',
                 kernel_initializer='he_uniform', 
                 padding='same')) # filter image by dot product in matrix to find the object in picture
# Hidden layers
model.add(MaxPooling2D(pool_size=(2,2))) # reduce stucture of image even if object slightly move but the result is same
model.add(Flatten()) # convert all the resultant 2-Dimensional arrays into a single long continuous linear vector
model.add(Dense(64, activation='relu',
                kernel_initializer='he_uniform'))

# avoid overfitting!
model.add(Dropout(0.5))

# Output layer
model.add(Dense(4, activation='softmax'))

# Compile the model         
model.compile(loss="categorical_crossentropy", 
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
# we have 2,102,564 nodes for training
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d_6 (MaxPoolin  (None, 112, 112, 16)      0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_7 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 16)        4624
#
#  max_pooling2d_8 (MaxPoolin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        4640
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 32)          9248
#
#  max_pooling2d_11 (MaxPooli  (None, 3, 3, 32)          0
#  ng2D)
#
#  flatten_1 (Flatten)         (None, 288)               0
#
#  dense_2 (Dense)             (None, 64)                18496
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 51604 (201.58 KB)
# Trainable params: 51604 (201.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Save checkpoints during training
checkpoint_path = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# training model 
# make sure you truely save checkpoint_path
history = model.fit(train_dataset,
                              epochs=25,
                              validation_data=valid_dataset,
                              callbacks=[cp_callback])
# Out:
# Epoch 1/25
# 557/557 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.6882
# Epoch 1: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 917s 2s/step - loss: 0.7470 - accuracy: 0.6882 - val_loss: 0.3461 - val_accuracy: 0.8884
# Epoch 2/25
# 557/557 [==============================] - ETA: 0s - loss: 0.3712 - accuracy: 0.8746
# Epoch 2: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 782s 1s/step - loss: 0.3712 - accuracy: 0.8746 - val_loss: 0.2360 - val_accuracy: 0.9223
# Epoch 3/25
# 557/557 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9073
# Epoch 3: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 757s 1s/step - loss: 0.2665 - accuracy: 0.9073 - val_loss: 0.1958 - val_accuracy: 0.9287
# Epoch 4/25
# 557/557 [==============================] - ETA: 0s - loss: 0.2343 - accuracy: 0.9217
# Epoch 4: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 747s 1s/step - loss: 0.2343 - accuracy: 0.9217 - val_loss: 0.1885 - val_accuracy: 0.9413
# Epoch 5/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9363
# Epoch 5: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 759s 1s/step - loss: 0.1918 - accuracy: 0.9363 - val_loss: 0.2908 - val_accuracy: 0.9056
# Epoch 6/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9456
# Epoch 6: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 748s 1s/step - loss: 0.1601 - accuracy: 0.9456 - val_loss: 0.1357 - val_accuracy: 0.9482
# Epoch 7/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9497
# Epoch 7: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 786s 1s/step - loss: 0.1546 - accuracy: 0.9497 - val_loss: 0.1213 - val_accuracy: 0.9591
# Epoch 8/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9563
# Epoch 8: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 776s 1s/step - loss: 0.1333 - accuracy: 0.9563 - val_loss: 0.1226 - val_accuracy: 0.9580
# Epoch 9/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9608
# Epoch 9: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 743s 1s/step - loss: 0.1178 - accuracy: 0.9608 - val_loss: 0.1281 - val_accuracy: 0.9557
# Epoch 10/25
# 557/557 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9617
# Epoch 10: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 793s 1s/step - loss: 0.1119 - accuracy: 0.9617 - val_loss: 0.1526 - val_accuracy: 0.9580
# Epoch 11/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9678
# Epoch 11: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 809s 1s/step - loss: 0.0938 - accuracy: 0.9678 - val_loss: 0.1143 - val_accuracy: 0.9597
# Epoch 12/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9739
# Epoch 12: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 1151s 2s/step - loss: 0.0770 - accuracy: 0.9739 - val_loss: 0.1174 - val_accuracy: 0.9557
# Epoch 13/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9717
# Epoch 13: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 1265s 2s/step - loss: 0.0822 - accuracy: 0.9717 - val_loss: 0.1029 - val_accuracy: 0.9689
# Epoch 14/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9721
# Epoch 14: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 1270s 2s/step - loss: 0.0823 - accuracy: 0.9721 - val_loss: 0.0970 - val_accuracy: 0.9701
# Epoch 15/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9748
# Epoch 15: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 945s 2s/step - loss: 0.0732 - accuracy: 0.9748 - val_loss: 0.0543 - val_accuracy: 0.9764
# Epoch 16/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9758
# Epoch 16: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 737s 1s/step - loss: 0.0766 - accuracy: 0.9758 - val_loss: 0.2188 - val_accuracy: 0.9200
# Epoch 17/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9760
# Epoch 17: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 727s 1s/step - loss: 0.0715 - accuracy: 0.9760 - val_loss: 0.0692 - val_accuracy: 0.9793
# Epoch 18/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9758
# Epoch 18: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 728s 1s/step - loss: 0.0732 - accuracy: 0.9758 - val_loss: 0.0820 - val_accuracy: 0.9707
# Epoch 19/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9826
# Epoch 19: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 725s 1s/step - loss: 0.0519 - accuracy: 0.9826 - val_loss: 0.1069 - val_accuracy: 0.9626
# Epoch 20/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9822
# Epoch 20: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 726s 1s/step - loss: 0.0561 - accuracy: 0.9822 - val_loss: 0.0681 - val_accuracy: 0.9747
# Epoch 21/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9815
# Epoch 21: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 724s 1s/step - loss: 0.0585 - accuracy: 0.9815 - val_loss: 0.0647 - val_accuracy: 0.9816
# Epoch 22/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9820
# Epoch 22: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 727s 1s/step - loss: 0.0594 - accuracy: 0.9820 - val_loss: 0.0821 - val_accuracy: 0.9747
# Epoch 23/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9827
# Epoch 23: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 723s 1s/step - loss: 0.0535 - accuracy: 0.9827 - val_loss: 0.0900 - val_accuracy: 0.9678
# Epoch 24/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9805
# Epoch 24: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 732s 1s/step - loss: 0.0598 - accuracy: 0.9805 - val_loss: 0.0655 - val_accuracy: 0.9799
# Epoch 25/25
# 557/557 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9871
# Epoch 25: saving model to C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model_cp\cp.ckpt
# 557/557 [==============================] - 727s 1s/step - loss: 0.0377 - accuracy: 0.9871 - val_loss: 0.0927 - val_accuracy: 0.9764

# %%
# plot graph 
plot_graph(history)

# %%
# save model
model.save(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\cnn_model.h5")
# Out:
# C:\Users\HP\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# create dataframe to save in .csv file
hist_df = pd.DataFrame(history.history) 
hist_df.head()

# Save history to CSV file
hist_csv_file = r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn-copy-2\history_cnn_model16.csv"
hist_df.to_csv(hist_csv_file, index=False)  # Set index=False to exclude the index column

# %% [markdown]
# ## Convert to TfLite

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model(r"C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn\cnn_model.h5")

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open(r'C:\Users\HP\Desktop\Data\poultry_disease_detection_third_iteration\models\cnn\cnn_model.tflite', 'wb') as f:
    f.write(tflite_model)
